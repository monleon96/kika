# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# Import the simplified module
from mcnpy.ace.analysis.cross_section_plotting import plot_cross_sections
from mcnpy import read_ace

# %%
# Replace these with paths to your ACE files
ace_file1 = "/home/MONLEON-JUAN/MCNPy/mcnpy/sampling/test_legendre/ace/293.6K/26056/0001/260560_33_0001.02c"  
ace_file2 = "/home/MONLEON-JUAN/MCNPy/mcnpy/sampling/test_legendre/ace/600.0K/26056/0001/260560_33_0001.06c" 
ace_file3 = "/home/MONLEON-JUAN/MCNPy/mcnpy/sampling/test_legendre/ace/293.6K/26056/0002/260560_33_0002.02c"

ace1 = read_ace(ace_file1)
ace2 = read_ace(ace_file2)
ace3 = read_ace(ace_file3)

ace_files = [ace1, ace2, ace3]
labels = ["sample01", "OG", "sample02"]  # Custom labels for the legend

# %%
# Plot total cross section (MT=1)
fig1 = plot_cross_sections(
    ace_files,
    mt_number=2,  
    labels=labels,
    energy_range=(1e-5, 1e-1),
    figsize=(10, 6),
    log_scale=True
)
plt.show()
# Out:
# /home/MONLEON-JUAN/MCNPy/mcnpy/ace/analysis/cross_section_plotting.py:247: UserWarning: The figure layout has changed to tight
#   fig.tight_layout()
