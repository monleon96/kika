# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

# Import the simplified module
from mcnpy.ace.analysis.cross_section_plotting import plot_cross_sections
from mcnpy import read_ace

# %%
# Replace these with paths to your ACE files
#ace_file1 = "/home/MONLEON-JUAN/MCNPy/mcnpy/sampling/test_endf_pert/ace/293.6K/26056/0001/260560_33_0001.02c"  
ace_file2 = "/home/MONLEON-JUAN/MCNPy/mcnpy/sampling/test_endf_pert/ace/600/26056/0001/260560_33_0001.06c" 
ace_file3 = "/home/MONLEON-JUAN/MCNPy/mcnpy/sampling/test_endf_pert/ace/600/26056/0002/260560_33_0002.06c"

#ace1 = read_ace(ace_file1)
ace2 = read_ace(ace_file2)
ace3 = read_ace(ace_file3)

ace_files = [ace2, ace3]
labels = ["sample01", "sample02"]

# %%
# Plot total cross section (MT=1)
fig1 = plot_cross_sections(
    ace_files,
    mt_number=2,  
    labels=labels,
    energy_range=(1e-4,1e-2),
    figsize=(10, 6),
)
plt.show()

# %%
import pandas as pd

parquet_file = "/home/MONLEON-JUAN/MCNPy/mcnpy/sampling/test_endf_pert/ace/600/perturbation_matrix_20250816_142959_master.parquet"

df = pd.read_parquet(parquet_file)

df
# Out:
#    Sample_ID  Fe56_MT2_E0-E1  Fe56_MT2_E1-E2  Fe56_MT2_E2-E3  Fe56_MT2_E3-E4  \
# 0          1        0.989892        0.989892        0.989892        0.989892
# 1          2        1.020667        1.020667        1.020667        1.020667
#
#    Fe56_MT2_E4-E5  Fe56_MT2_E5-E6  Fe56_MT2_E6-E7  Fe56_MT2_E7-E8  \
# 0        0.989892        0.989892        0.989892        0.989892
# 1        1.020667        1.020667        1.020667        1.020667
#
#    Fe56_MT2_E8-E9  ...  Fe56_MT2_E46-E47  Fe56_MT2_E47-E48  Fe56_MT2_E48-E49  \
# 0        0.989920  ...          1.032166          1.024788          1.024788
# 1        1.020791  ...          1.011485          1.012158          1.012158
#
#    Fe56_MT2_E49-E50  Fe56_MT2_E50-E51  Fe56_MT2_E51-E52  Fe56_MT2_E52-E53  \
# 0          1.024788          0.972654          0.919965          0.916628
# 1          1.012158          1.058103          1.106929          1.061584
#
#    Fe56_MT2_E53-E54  Fe56_MT2_E54-E55  Fe56_MT2_E55-E56
# ...
