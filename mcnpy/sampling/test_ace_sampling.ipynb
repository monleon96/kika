# %%
import os
import mcnpy
from mcnpy.sampling.ace_perturbation import perturb_ACE_files

# %%
# 1) Paths to ACE files
ace_H1   = '/soft_snc/lib/ace/81/600/10010_81.06c'
acelist = [ace_H1]

cov_H1    = '/soft_snc/lib/cov/81/600/10010_81.06.xs.gendf'    
covlist = [cov_H1]

# %%
# 3) Running parameters
mt_numbers   = [2]
num_samples  = 4
output_dir   = "./test_ace_pert"
xsdir_file   = "/share_snc/snc/JuanMonleon/xsdir/xsdir80-irdff2"
seed         = 42
nprocs       = 1
dry_run      = False
autofix 	 = 'soft'
accept_tol   = -1.0e-4

# %%
# 2) Call the new perturb_ace_files
perturb_ACE_files(
    ace_files            = acelist,
    cov_files            = covlist,
    mt_list              = mt_numbers,
    num_samples          = num_samples,
    space                = "log",
    decomposition_method = "svd",
    sampling_method      = "sobol",
    output_dir           = output_dir,
    xsdir_file           = xsdir_file,
    seed                 = seed,
    nprocs               = nprocs,
    dry_run              = dry_run,    
    autofix              = autofix,
    accept_tol		     = accept_tol
)
# Out:
# [INFO] Starting ACE perturbation job
# [INFO] Log file: ./test_ace_pert/ace_perturbation_20250811_130716.log
# [INFO] Output directory: /home/MONLEON-JUAN/MCNPy/mcnpy/sampling/test_ace_pert
# [INFO] Processing 1 isotope(s)
# [INFO] Matrix directory: perturbation_matrix_20250811_130716
#
# [INFO] Processing isotope 1/1: 10010_81.06c
# [INFO] Generating 4 samples for ZAID 1001
# [DECOMPOSITION] Computing SVD in log space
# [COV] [SVD] Clipped 25 negative eigenvalues before SVD (min=-6.479e-10)
#
# [DECOMPOSITION] [QUALITY] SVD in log space
# ------------------------------------------------------------
#   Relative Frobenius error: 0.000028%
#   Max diagonal error: 0.000387%
#   Max off-diagonal error: 0.000002%
#   Quality assessment: GOOD
# ------------------------------------------------------------
# [INFO] Completed ACE generation for ZAID 1001
#
# [INFO] Job completed!
# [INFO] Processed: 1 isotope(s)
# [INFO] Skipped: 0 isotope(s)
# ...
