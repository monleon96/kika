# %%
import mcnpy
from comparison import compare_ace_files

# %%
acefile_original = '922350_71.02c'
acefile_rewrite = '92235_0K.ace'

# %%
acefile_original = '10010_71.02c'
acefile_rewrite = '1001_0K.ace'

# %%
ace_original = mcnpy.read_ace(acefile_original)
ace_rewrite = mcnpy.read_ace(acefile_rewrite)

# %%
result = compare_ace_files(acefile_original, acefile_rewrite, tolerance=1e-6, verbose=False)
print(f"Files are {'equivalent' if result else 'different'}")
# Out:
# Files are equivalent
