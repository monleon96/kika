# %%
import mcnpy
from write_ace import write_ace

# %%
acefile = '../files/260560_80.02c'
#acefile = '../files/922350_71.02c'

# %%
ace = mcnpy.read_ace(acefile)

# %%
write_ace(ace, overwrite=True)
# Out:
# Using modified original filename: ../files/260560_80_recon.02c
# 'Success! ACE file written to: ../files/260560_80_recon.02c'
