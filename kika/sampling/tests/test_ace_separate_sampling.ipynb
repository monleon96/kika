# %%
import importlib
import sys

# Reload the module to get the latest changes
if 'kika.sampling.ace_perturbation_separate' in sys.modules:
    importlib.reload(sys.modules['kika.sampling.ace_perturbation_separate'])

from kika.sampling.ace_perturbation_separate import perturb_seprate_ACE_files

# %%
# Example parameters - adjust these to match your actual setup
root_dir = "/home/MONLEON-JUAN/KIKA/kika/sampling/test_endf_pert"  # Root directory containing ace/ subdirectory
temperatures = [600] 
zaids = [26056]  
cov_files = "/soft_snc/lib/cov/33/293.6/260560_33.02.xs.gendf"  # Single covariance file for all ZAIDs
# Or use multiple covariance files: cov_files = ["file1.cov", "file2.cov", "file3.cov"]

mt_list = [2]  # MT numbers to perturb, or [] for all available
num_samples = 2  # Number of perturbation samples (must match existing ACE files)

print("✅ Configuration updated - ready to test!")
# Out:
# ✅ Configuration updated - ready to test!

# %%
# Call the updated function
perturb_seprate_ACE_files(
    root_dir=root_dir,
    temperatures=temperatures,
    zaids=zaids,
    cov_files=cov_files,
    mt_list=mt_list,
    num_samples=num_samples,
    space="log",  # "linear" or "log"
    decomposition_method="svd",  # "svd", "cholesky", "eigen", or "pca"
    sampling_method="sobol",  # "sobol", "lhs", or "random"
    seed=42,  # For reproducible results
    nprocs=1,  # Number of parallel processes
    dry_run=False,  # Set to True to only generate factors without modifying files
    autofix="soft",  # Covariance matrix autofix level: None, "soft", "medium", "hard"
    verbose=True
)
# Out:
# [INFO] Starting ACE perturbation job
# [INFO] Log file: /home/MONLEON-JUAN/KIKA/kika/sampling/test_endf_pert/ace_perturbation_20250816_145320.log
# [INFO] Root directory: /home/MONLEON-JUAN/KIKA/kika/sampling/test_endf_pert
# [INFO] Processing 1 isotope(s)
# [INFO] Matrix directory: perturbation_matrix_20250816_145320
#
# [INFO] Processing isotope 1/1: ZAID 26056
# [INFO] Generating 2 samples for ZAID 26056
#   [ITERATION 01] Scanning variance values
#   [ITERATION 01] No variances above threshold; stopping clamping
#
# [COVARIANCE] [STRUCTURE DIAGNOSTICS]
# ------------------------------------------------------------
#   ✓ Covariance matrix structure: PASS (max σ²=0.01)
# ------------------------------------------------------------
# [DECOMPOSITION] Computing SVD in log space
# [COV] [SVD] Clipped 23 negative eigenvalues before SVD (min=-4.691e-06)
#
# [DECOMPOSITION] [QUALITY] SVD in log space
# ------------------------------------------------------------
#   Relative Frobenius error: 0.004689%
#   Max diagonal error: 0.106740%
#   Max off-diagonal error: 0.000799%
#   Quality assessment: ACCEPTABLE
# ------------------------------------------------------------
#
# [SAMPLING] [LOG SPACE DIAGNOSTICS]
# ------------------------------------------------------------
#   📊 Technical Summary:
#     • Log-space covariance reproduction (Frobenius): 143.69%
#     • Mean deviations: 0/56 parameters outside z±3.0
#   ❌ Overall Status: FAIL
#   ✓ All sample dimensions within acceptable thresholds.
# ------------------------------------------------------------
# [INFO] Completed ACE perturbation for ZAID 26056
#
# [INFO] Job completed!
# [INFO] Processed: 1 isotope(s)
# [INFO] Skipped: 0 isotope(s)
# [INFO] Detailed log saved to: /home/MONLEON-JUAN/KIKA/kika/sampling/test_endf_pert/ace_perturbation_20250816_145320.log
# [INFO] Master matrix file copied to temperature directories
