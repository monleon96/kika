# %%
import kika
from write_ace import write_ace

# %%
acefile = '../files/260560_80.02c'
acefile = '../files/922350_71.02c'

# %%
ace = kika.read_ace(acefile)

# %%
#ace_copy = ace.copy()

# %%
write_ace(ace, filepath='test_writing.02c', overwrite=True)
# Out:
# 'Success! ACE file written to: test_writing.02c'

# %% [markdown]
# read = 5.5s
#
# copy = 34.6s
#
# write = 8.0s
