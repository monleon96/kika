# %%
import mcnpy

# %%
filename = "/home/MONLEON-JUAN/MCNPy/tests/data/F4PertTally_test1.m"

mctal = mcnpy.read_mctal(filename)

# %%
for i in range(0):
    print(i)

# %%
mctal.tally[4].pert_data[1].results
# Out:
# [0.0, 0.0, 0.0]

# %%
mctal.tally[4].energies
# Out:
# [0.1, 1.0, 3.0]

# %%
mctal.tally[4].plot_tfc_data();

# %%
mctal.tally[4].pert_data[473].plot_tfc_data();
