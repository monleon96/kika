# %%
import mcnpy
from pathlib import Path

# %%
repo_root = Path.cwd().resolve().parent
inputfile = repo_root / 'examples' / 'data' / 'PWRSphere_test copy.i'

# %%
outputpath = repo_root / 'examples'

# %%
mcnpy.perturb_material(inputfile, 300000, 8.526729e-02, 26056, 42, False)
# Out:
# Perturbation details:
# - Original material: 300000
# - Perturbed material ID: 42
# - Perturbed nuclide: 26056
# - Original density: 8.526729e-02 atoms/barn-cm | 7.850001e+00 g/cm³
# - Perturbed density: 1.603930e-01 atoms/barn-cm | 2.789207e+01 g/cm³
#
# Success! Material written to: /home/MONLEON-JUAN/MCNPy/examples/data/PWRSphere_test copy_perturbed_m300000_n26056.i
