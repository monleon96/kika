# %%
import mcnpy
from pathlib import Path

# %%
repo_root = Path.cwd().resolve().parent
inputfile = repo_root / 'examples' / 'data' / 'PWRSphere_test copy.i'

# %%
cell = [1,2,4]
rho = 1.13e-3
reactions = [101, 102]
energies = mcnpy.energyGrids.scale44
material = 1001
order = 2
errors = False

# %%
mcnpy.generate_PERTcards(inputfile, cell, rho, reactions, energies, material, order, errors)
# Out:
# Success! PERT cards written to: /home/MONLEON-JUAN/MCNPy/examples/data/PWRSphere_test copy.i
