# %%
import mcnpy
from pathlib import Path

# %%
repo_root = Path.cwd().resolve().parent
outputfile = repo_root / 'examples' / 'pert_example.i'

# %%
cell = [1,2,4]
rho = 1.13e-3
reactions = [101, 102]
energies = mcnpy.energyGrids.scale44
material = 1001
order = 2
errors = False

# %%
mcnpy.generate_PERTcards(cell, rho, reactions, energies, material, order, errors, outputfile)
# Out:
# Success! PERT cards written to: /home/MONLEON-JUAN/MCNPy/examples/pert_example.i

# %%
mcnpy.generate_PERTcards(cell, rho, reactions, energies, material, order, errors)
# Out:
# c ==============================================================================
# c ========================== Added with MCNPy ==================================
# c ==============================================================================
# c
# PERT1:n CELL=1,2,4 MAT=1001 &
# RHO=1.130000e-03 METHOD=2 RXN=101 ERG=1.000000e-11 3.000000e-09
# PERT2:n CELL=1,2,4 MAT=1001 &
# RHO=1.130000e-03 METHOD=3 RXN=101 ERG=1.000000e-11 3.000000e-09
# PERT3:n CELL=1,2,4 MAT=1001 &
# RHO=1.130000e-03 METHOD=2 RXN=101 ERG=3.000000e-09 7.500000e-09
# PERT4:n CELL=1,2,4 MAT=1001 &
# RHO=1.130000e-03 METHOD=3 RXN=101 ERG=3.000000e-09 7.500000e-09
# PERT5:n CELL=1,2,4 MAT=1001 &
# RHO=1.130000e-03 METHOD=2 RXN=101 ERG=7.500000e-09 1.000000e-08
# PERT6:n CELL=1,2,4 MAT=1001 &
# RHO=1.130000e-03 METHOD=3 RXN=101 ERG=7.500000e-09 1.000000e-08
# PERT7:n CELL=1,2,4 MAT=1001 &
# RHO=1.130000e-03 METHOD=2 RXN=101 ERG=1.000000e-08 2.530000e-08
# PERT8:n CELL=1,2,4 MAT=1001 &
# ...
