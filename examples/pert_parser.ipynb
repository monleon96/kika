# %%
import mcnpy

# %%
pertfile = '/home/MONLEON-JUAN/MCNPy/tests/data/PERT.i'

input = mcnpy.read_mcnp(pertfile)

# %%
input.pert.perturbation
# Out:
# {1: Perturbation(id=1, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=2, reaction=1, energy=(1e-11, 3e-09)),
#  2: Perturbation(id=2, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=3, reaction=1, energy=(1e-11, 3e-09)),
#  3: Perturbation(id=3, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-2, reaction=1, energy=(1e-11, 3e-09)),
#  4: Perturbation(id=4, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-3, reaction=1, energy=(1e-11, 3e-09)),
#  5: Perturbation(id=5, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=1, reaction=1, energy=(1e-11, 3e-09)),
#  6: Perturbation(id=6, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=2, reaction=1, energy=(3e-09, 7.5e-09)),
#  7: Perturbation(id=7, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=3, reaction=1, energy=(3e-09, 7.5e-09)),
# ...

# %%
dicc = input.pert.group_perts_by_reaction(2)
dicc
# Out:
# {1: [1,
#   6,
#   11,
#   16,
#   21,
#   26,
#   31,
#   36,
#   41,
#   46,
#   51,
#   56,
#   61,
#   66,
#   71,
#   76,
#   81,
#   86,
#   91,
#   96,
#   101,
#   106,
#   111,
#   116,
#   121,
#   126,
#   131,
#   136,
#   141,
#   146,
#   151,
#   156,
#   161,
#   166,
#   171,
#   176,
#   181,
#   186,
#   191,
#   196,
#   201,
#   206,
#   211,
#   216],
#  2: [221,
#   226,
#   231,
#   236,
#   241,
#   246,
#   251,
#   256,
#   261,
#   266,
#   271,
#   276,
#   281,
#   286,
#   291,
#   296,
#   301,
#   306,
#   311,
#   316,
#   321,
#   326,
#   331,
#   336,
#   341,
#   346,
#   351,
#   356,
#   361,
#   366,
#   371,
#   376,
#   381,
#   386,
#   391,
#   396,
#   401,
#   406,
#   411,
#   416,
#   421,
#   426,
#   431,
#   436],
#  4: [441,
#   446,
#   451,
#   456,
#   461,
#   466,
#   471,
#   476,
#   481,
#   486,
#   491,
#   496,
#   501,
#   506,
#   511,
#   516,
#   521,
#   526,
#   531,
#   536,
#   541,
#   546,
#   551,
#   556,
# ...

# %%
input.pert.pert_energies
# Out:
# [1e-11,
#  3e-09,
#  7.5e-09,
#  1e-08,
#  2.53e-08,
#  3e-08,
#  4e-08,
#  5e-08,
#  7e-08,
#  1e-07,
#  1.5e-07,
#  2e-07,
#  2.25e-07,
#  2.5e-07,
#  2.75e-07,
#  3.25e-07,
#  3.5e-07,
#  3.75e-07,
#  4e-07,
#  6.25e-07,
#  1e-06,
#  1.77e-06,
#  3e-06,
#  4.75e-06,
#  6e-06,
#  8.1e-06,
#  1e-05,
#  3e-05,
#  0.0001,
#  0.00055,
#  0.003,
#  0.017,
#  0.025,
#  0.1,
#  0.4,
#  0.9,
#  1.4,
#  1.85,
#  2.354,
#  2.479,
#  3.0,
#  4.8,
#  6.434,
#  8.1873,
#  20.0]
