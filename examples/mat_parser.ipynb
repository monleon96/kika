# %%
import mcnpy
from pathlib import Path

# %%
repo_root = Path.cwd()
matfile = repo_root / 'tests' / 'data' / 'mat' / 'mat_test1.i'

# %%
print(matfile.resolve())
# Out:
# C:\Users\Usuario\BaradDur\Repositorios\MCNPy\examples\tests\data\mat\mat_test1.i

# %%
input = mcnpy.read_mcnp(matfile)
materials = input.materials
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 input = mcnpy.read_mcnp(matfile)
#       2 materials = input.materials
#
# File ~\BaradDur\Repositorios\MCNPy\mcnpy\input\parse_input.py:197, in read_mcnp(file_path)
#     194 inst.pert = Pert()
#     195 inst.materials = Materials()
# --> 197 with open(file_path, 'r') as f:
#     198     lines = f.readlines()
#     200 i = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\Usuario\\BaradDur\\Repositorios\\MCNPy\\examples\\tests\\data\\mat\\mat_test1.i'

# %%
materials.mat[300000]
# Out:
# Mat(id=300000, nlib='06c', plib='02p', components={6012: {'fraction': 0.009126127, 'nlib': None, 'plib': None, 'nuclide': 'C'}, 6013: {'fraction': 0.0001022318, 'nlib': '03c', 'plib': '04p', 'nuclide': 'C'}, 23050: {'fraction': 2.719838e-07, 'nlib': None, 'plib': None, 'nuclide': 'V'}, 23051: {'fraction': 0.0001085216, 'nlib': None, 'plib': None, 'nuclide': 'V'}, 24050: {'fraction': 0.0001159138, 'nlib': None, 'plib': None, 'nuclide': 'Cr'}, 24052: {'fraction': 0.002232735, 'nlib': None, 'plib': None, 'nuclide': 'Cr'}, 24053: {'fraction': 0.0002531442, 'nlib': None, 'plib': None, 'nuclide': 'Cr'}, 24054: {'fraction': 6.288632e-05, 'nlib': None, 'plib': None, 'nuclide': 'Cr'}, 28058: {'fraction': 0.004190792, 'nlib': None, 'plib': None, 'nuclide': 'Ni'}, 28060: {'fraction': 0.001601455, 'nlib': None, 'plib': None, 'nuclide': 'Ni'}, 28061: {'fraction': 6.933523e-05, 'nlib': None, 'plib': None, 'nuclide': 'Ni'}, 28062: {'fraction': 0.0002202771, 'nlib': None, 'plib': None, 'nuclide': 'Ni'}, 28064: {'fraction': 5.583628e-05, 'nlib': None, 'plib': None, 'nuclide': 'Ni'}, 42092: {'fraction': 0.0004274704, 'nlib': None, 'plib': None, 'nuclide': 'Mo'}, 42094: {'fraction': 0.0002686133, 'nlib': None, 'plib': None, 'nuclide': 'Mo'}, 42095: {'fraction': 0.0004592415, 'nlib': None, 'plib': None, 'nuclide': 'Mo'}, 42096: {'fraction': 0.000482348, 'nlib': None, 'plib': None, 'nuclide': 'Mo'}, 42097: {'fraction': 0.0002772778, 'nlib': None, 'plib': None, 'nuclide': 'Mo'}, 42098: {'fraction': 0.0006960837, 'nlib': None, 'plib': None, 'nuclide': 'Mo'}, 42100: {'fraction': 0.0002772778, 'nlib': None, 'plib': None, 'nuclide': 'Mo'}, 14028: {'fraction': 0.003639863, 'nlib': None, 'plib': None, 'nuclide': 'Si'}, 14029: {'fraction': 0.0001843021, 'nlib': None, 'plib': None, 'nuclide': 'Si'}, 14030: {'fraction': 0.000122342, 'nlib': None, 'plib': None, 'nuclide': 'Si'}, 25055: {'fraction': 0.01361868, 'nlib': None, 'plib': None, 'nuclide': 'Mn'}, 15031: {'fraction': 0.0001431432, 'nlib': None, 'plib': None, 'nuclide': 'P'}, 16032: {'fraction': 0.0001314059, 'nlib': None, 'plib': None, 'nuclide': 'S'}, 16033: {'fraction': 1.0372e-06, 'nlib': None, 'plib': None, 'nuclide': 'S'}, 16034: {'fraction': 5.822139e-06, 'nlib': None, 'plib': None, 'nuclide': 'S'}, 16036: {'fraction': 2.350983e-08, 'nlib': None, 'plib': None, 'nuclide': 'S'}, 29063: {'fraction': 0.0004828165, 'nlib': None, 'plib': None, 'nuclide': 'Cu'}, 29065: {'fraction': 0.0002148952, 'nlib': None, 'plib': None, 'nuclide': 'Cu'}, 27059: {'fraction': 0.0002821213, 'nlib': None, 'plib': None, 'nuclide': 'Co'}, 26054: {'fraction': 0.05566621, 'nlib': None, 'plib': None, 'nuclide': 'Fe'}, 26056: {'fraction': 0.8810613, 'nlib': None, 'plib': None, 'nuclide': 'Fe'}, 26057: {'fraction': 0.02063485, 'nlib': None, 'plib': None, 'nuclide': 'Fe'}, 26058: {'fraction': 0.002783306, 'nlib': None, 'plib': None, 'nuclide': 'Fe'}})

# %%
print(materials.mat[300000])
# Out:
# m300000 nlib=06c plib=02p
#     6012 9.126127e-03
#     6012 9.126127e-03
#     6013.03c 1.022318e-04
#     6013.04p 1.022318e-04
#     23050 2.719838e-07
#     23050 2.719838e-07
#     23051 1.085216e-04
#     23051 1.085216e-04
#     24050 1.159138e-04
#     24050 1.159138e-04
#     24052 2.232735e-03
#     24052 2.232735e-03
#     24053 2.531442e-04
#     24053 2.531442e-04
#     24054 6.288632e-05
#     24054 6.288632e-05
#     28058 4.190792e-03
#     28058 4.190792e-03
#     28060 1.601455e-03
#     28060 1.601455e-03
#     28061 6.933523e-05
#     28061 6.933523e-05
#     28062 2.202771e-04
#     28062 2.202771e-04
#     28064 5.583628e-05
#     28064 5.583628e-05
#     42092 4.274704e-04
#     42092 4.274704e-04
#     42094 2.686133e-04
#     42094 2.686133e-04
#     42095 4.592415e-04
#     42095 4.592415e-04
#     42096 4.823480e-04
#     42096 4.823480e-04
#     42097 2.772778e-04
#     42097 2.772778e-04
#     42098 6.960837e-04
#     42098 6.960837e-04
#     42100 2.772778e-04
#     42100 2.772778e-04
#     14028 3.639863e-03
#     14028 3.639863e-03
#     14029 1.843021e-04
#     14029 1.843021e-04
#     14030 1.223420e-04
#     14030 1.223420e-04
#     25055 1.361868e-02
#     25055 1.361868e-02
#     15031 1.431432e-04
#     15031 1.431432e-04
#     16032 1.314059e-04
#     16032 1.314059e-04
#     16033 1.037200e-06
#     16033 1.037200e-06
#     16034 5.822139e-06
#     16034 5.822139e-06
#     16036 2.350983e-08
#     16036 2.350983e-08
#     29063 4.828165e-04
#     29063 4.828165e-04
#     29065 2.148952e-04
#     29065 2.148952e-04
#     27059 2.821213e-04
#     27059 2.821213e-04
#     26054 5.566621e-02
#     26054 5.566621e-02
#     26056 8.810613e-01
#     26056 8.810613e-01
#     26057 2.063485e-02
#     26057 2.063485e-02
#     26058 2.783306e-03
#     26058 2.783306e-03

# %%
materials.mat[300000].components
# Out:
# {6012: {'fraction': 0.009126127, 'nlib': None, 'plib': None, 'nuclide': 'C'},
#  6013: {'fraction': 0.0001022318,
#   'nlib': '03c',
#   'plib': '04p',
#   'nuclide': 'C'},
#  23050: {'fraction': 2.719838e-07, 'nlib': None, 'plib': None, 'nuclide': 'V'},
#  23051: {'fraction': 0.0001085216, 'nlib': None, 'plib': None, 'nuclide': 'V'},
#  24050: {'fraction': 0.0001159138,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Cr'},
#  24052: {'fraction': 0.002232735, 'nlib': None, 'plib': None, 'nuclide': 'Cr'},
#  24053: {'fraction': 0.0002531442,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Cr'},
#  24054: {'fraction': 6.288632e-05,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Cr'},
#  28058: {'fraction': 0.004190792, 'nlib': None, 'plib': None, 'nuclide': 'Ni'},
#  28060: {'fraction': 0.001601455, 'nlib': None, 'plib': None, 'nuclide': 'Ni'},
#  28061: {'fraction': 6.933523e-05,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Ni'},
#  28062: {'fraction': 0.0002202771,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Ni'},
#  28064: {'fraction': 5.583628e-05,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Ni'},
#  42092: {'fraction': 0.0004274704,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Mo'},
#  42094: {'fraction': 0.0002686133,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Mo'},
#  42095: {'fraction': 0.0004592415,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Mo'},
#  42096: {'fraction': 0.000482348, 'nlib': None, 'plib': None, 'nuclide': 'Mo'},
#  42097: {'fraction': 0.0002772778,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Mo'},
#  42098: {'fraction': 0.0006960837,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Mo'},
#  42100: {'fraction': 0.0002772778,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Mo'},
#  14028: {'fraction': 0.003639863, 'nlib': None, 'plib': None, 'nuclide': 'Si'},
#  14029: {'fraction': 0.0001843021,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Si'},
#  14030: {'fraction': 0.000122342, 'nlib': None, 'plib': None, 'nuclide': 'Si'},
#  25055: {'fraction': 0.01361868, 'nlib': None, 'plib': None, 'nuclide': 'Mn'},
#  15031: {'fraction': 0.0001431432, 'nlib': None, 'plib': None, 'nuclide': 'P'},
#  16032: {'fraction': 0.0001314059, 'nlib': None, 'plib': None, 'nuclide': 'S'},
#  16033: {'fraction': 1.0372e-06, 'nlib': None, 'plib': None, 'nuclide': 'S'},
#  16034: {'fraction': 5.822139e-06, 'nlib': None, 'plib': None, 'nuclide': 'S'},
#  16036: {'fraction': 2.350983e-08, 'nlib': None, 'plib': None, 'nuclide': 'S'},
#  29063: {'fraction': 0.0004828165,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Cu'},
#  29065: {'fraction': 0.0002148952,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Cu'},
#  27059: {'fraction': 0.0002821213,
#   'nlib': None,
#   'plib': None,
#   'nuclide': 'Co'},
#  26054: {'fraction': 0.05566621, 'nlib': None, 'plib': None, 'nuclide': 'Fe'},
#  26056: {'fraction': 0.8810613, 'nlib': None, 'plib': None, 'nuclide': 'Fe'},
#  26057: {'fraction': 0.02063485, 'nlib': None, 'plib': None, 'nuclide': 'Fe'},
#  26058: {'fraction': 0.002783306, 'nlib': None, 'plib': None, 'nuclide': 'Fe'}}

# %%
input
# Out:
# Input(pert=Pert(perturbation={1: Perturbation(id=1, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=2, reaction=1, energy=(1e-11, 3e-09)), 2: Perturbation(id=2, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=3, reaction=1, energy=(1e-11, 3e-09)), 3: Perturbation(id=3, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-2, reaction=1, energy=(1e-11, 3e-09)), 4: Perturbation(id=4, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-3, reaction=1, energy=(1e-11, 3e-09)), 5: Perturbation(id=5, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=1, reaction=1, energy=(1e-11, 3e-09)), 6: Perturbation(id=6, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=2, reaction=1, energy=(3e-09, 7.5e-09)), 7: Perturbation(id=7, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=3, reaction=1, energy=(3e-09, 7.5e-09)), 8: Perturbation(id=8, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-2, reaction=1, energy=(3e-09, 7.5e-09)), 9: Perturbation(id=9, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-3, reaction=1, energy=(3e-09, 7.5e-09)), 10: Perturbation(id=10, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=1, reaction=1, energy=(3e-09, 7.5e-09)), 11: Perturbation(id=11, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=2, reaction=1, energy=(7.5e-09, 1e-08)), 12: Perturbation(id=12, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=3, reaction=1, energy=(7.5e-09, 1e-08)), 13: Perturbation(id=13, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-2, reaction=1, energy=(7.5e-09, 1e-08)), 14: Perturbation(id=14, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-3, reaction=1, energy=(7.5e-09, 1e-08)), 15: Perturbation(id=15, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=1, reaction=1, energy=(7.5e-09, 1e-08)), 16: Perturbation(id=16, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=2, reaction=1, energy=(1e-08, 2.53e-08)), 17: Perturbation(id=17, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=3, reaction=1, energy=(1e-08, 2.53e-08)), 18: Perturbation(id=18, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-2, reaction=1, energy=(1e-08, 2.53e-08)), 19: Perturbation(id=19, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-3, reaction=1, energy=(1e-08, 2.53e-08)), 20: Perturbation(id=20, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=1, reaction=1, energy=(1e-08, 2.53e-08)), 21: Perturbation(id=21, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=2, reaction=1, energy=(2.53e-08, 3e-08)), 22: Perturbation(id=22, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=3, reaction=1, energy=(2.53e-08, 3e-08)), 23: Perturbation(id=23, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-2, reaction=1, energy=(2.53e-08, 3e-08)), 24: Perturbation(id=24, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-3, reaction=1, energy=(2.53e-08, 3e-08)), 25: Perturbation(id=25, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=1, reaction=1, energy=(2.53e-08, 3e-08)), 26: Perturbation(id=26, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=2, reaction=1, energy=(3e-08, 4e-08)), 27: Perturbation(id=27, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=3, reaction=1, energy=(3e-08, 4e-08)), 28: Perturbation(id=28, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-2, reaction=1, energy=(3e-08, 4e-08)), 29: Perturbation(id=29, particle='n', cell=[3, 5, 7, 9], material=300001, rho=0.160393, method=-3, reaction=1, energy=(3e-08, 4e-08)), 30: Perturbation(id=30, particle='n', ce ...
